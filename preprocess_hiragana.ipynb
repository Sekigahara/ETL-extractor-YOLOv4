# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from scipy import ndimage

# %%
train_load = np.load("Utils\\dataset_train.npz")
test_load = np.load("Utils\\dataset_test.npz")

# %%
# Get train Data
x_train_path = train_load['x_path']
#y_train = train_load['y_train']
#y_train_not_encoded = train_load['y_train_raw']

# %%
# Get Test Data
x_test_path = test_load['x_path']
#y_test = test_load['y_train']
#y_test_not_encoded = test_load['y_train_raw']

# %%
from dataset.hiragana import basic_hiragana_char
from dataset.katakana import basic_katakana_char

# Make List of Label in One Array
japanese_character = []
japanese_character.extend(basic_hiragana_char)
japanese_character.extend(basic_katakana_char)

# %%
# Load Data Test
x_test = []
y_test = []
for idx, path in enumerate(x_test_path):
    # Check do the classes is katakana
    type_chara = x_test_path[idx].split("//")[2].split("_")[2].split(".")[0]
    if type_chara == "kana":
        continue    

    label = x_test_path[idx].split("//")[2].split("\\")[1].split("_")[1]
    y_test.append(label)
       
    img_temp = cv2.imread(path)
    img_temp = cv2.cvtColor(img_temp, cv2.COLOR_BGR2RGB)
    x_test.append(img_temp)

# %%
y_test
# Out:
# ['も-mo',
#  'や-ya',
#  'ら-ra',
#  'る-ru',
#  'あ-a',
#  'き-ki',
#  'く-ku',
#  'ち-chi',
#  'つ-tsu',
#  'な-na',
#  'の-no',
#  'ひ-hi',
#  'ま-ma',
#  'や-ya',
#  'す-su',
#  'ら-ra',
#  'れ-re',
#  'ん-n',
#  'け-ke',
#  'そ-so',
#  'に-ni',
#  'ふ-fu',
#  'み-mi',
#  'も-mo',
#  'ろ-ro',
#  'わ-wa',
#  'く-ku',
#  'す-su',
#  'せ-se',
#  'つ-tsu',
#  'の-no',
#  'ひ-hi',
#  'ふ-fu',
#  'ま-ma',
#  'に-ni',
#  'ろ-ro',
#  'ん-n',
#  'か-ka',
#  'く-ku',
#  'こ-ko',
#  'ね-ne',
#  'た-ta',
#  'ち-chi',
#  'と-to',
#  'な-na',
#  'ね-ne',
#  'の-no',
#  'へ-he',
#  'ほ-ho',
#  'は-ha',
#  'ま-ma',
#  'み-mi',
#  'ら-ra',
#  'し-shi',
#  'お-o',
#  'さ-sa',
#  'し-shi',
#  'そ-so',
#  'と-to',
#  'ね-ne',
#  'ほ-ho',
#  'ひ-hi',
#  'ほ-ho',
#  'ま-ma',
#  'れ-re',
#  'ろ-ro',
#  'み-mi',
#  'い-i',
#  'く-ku',
#  'そ-so',
#  'た-ta',
#  'と-to',
#  'ひ-hi',
#  'へ-he',
#  'め-me',
#  'も-mo',
#  'や-ya',
#  'あ-a',
#  'し-shi',
#  'そ-so',
#  'と-to',
#  'よ-yo',
#  'ら-ra',
#  'り-ri',
#  'る-ru',
#  'ん-n',
#  'う-u',
#  'え-e',
#  'ち-chi',
#  'な-na',
#  'の-no',
#  'へ-he',
#  'を-o',
#  'ん-n',
#  'あ-a',
#  'え-e',
#  'お-o',
#  'か-ka',
#  'せ-se',
#  'い-i',
#  'せ-se',
#  'ね-ne',
#  'ふ-fu',
#  'め-me',
#  'ゆ-yu',
#  'ろ-ro',
#  'あ-a',
#  'お-o',
#  'す-su',
#  'そ-so',
#  'と-to',
#  'ね-ne',
#  'へ-he',
#  'み-mi',
#  'む-mu',
#  'く-ku',
#  'や-ya',
#  'ら-ra',
#  'り-ri',
#  'ろ-ro',
#  'あ-a',
#  'う-u',
#  'お-o',
#  'き-ki',
#  'け-ke',
#  'さ-sa',
#  'す-su',
#  'せ-se',
#  'て-te',
#  'ひ-hi',
#  'め-me',
#  'ゆ-yu',
#  'す-su',
#  'り-ri',
#  'ん-n',
#  'に-ni',
#  'ね-ne',
#  'め-me',
#  'ら-ra',
#  'り-ri',
#  'る-ru',
#  'れ-re',
#  'か-ka',
#  'て-te',
#  'き-ki',
#  'し-shi',
#  'と-to',
#  'な-na',
#  'は-ha',
#  'ひ-hi',
#  'も-mo',
#  'に-ni',
#  'ゆ-yu',
#  'り-ri',
#  'る-ru',
#  'い-i',
#  'え-e',
#  'か-ka',
#  'さ-sa',
#  'し-shi',
#  'せ-se',
#  'と-to',
#  'に-ni',
#  'ふ-fu',
#  'み-mi',
#  'め-me',
#  'も-mo',
#  'ゆ-yu',
#  'る-ru',
#  'を-o',
#  'ん-n',
#  'ふ-fu',
#  'か-ka',
#  'き-ki',
#  'く-ku',
#  'へ-he',
#  'そ-so',
#  'ち-chi',
#  'と-to',
#  'ね-ne',
#  'の-no',
#  'は-ha',
#  'へ-he',
#  'や-ya',
#  'い-i',
#  'か-ka',
#  'し-shi',
#  'そ-so',
#  'め-me',
#  'て-te',
#  'ぬ-nu',
#  'ね-ne',
#  'ほ-ho',
#  'ま-ma',
#  'む-mu',
#  'め-me',
#  'ゆ-yu',
#  'ら-ra',
#  'り-ri',
#  'る-ru',
#  'わ-wa',
#  'ゆ-yu',
#  'か-ka',
#  'き-ki',
#  'せ-se',
#  'そ-so',
#  'ち-chi',
#  'ら-ra',
#  'ね-ne',
#  'の-no',
#  'ふ-fu',
#  'へ-he',
#  'み-mi',
#  'ら-ra',
#  'る-ru',
#  'る-ru',
#  'ろ-ro',
#  'を-o',
#  'あ-a',
#  'う-u',
#  'え-e',
#  'く-ku',
#  'し-shi',
#  'ろ-ro',
#  'ち-chi',
#  'む-mu',
#  'ん-n',
#  'こ-ko',
#  'せ-se',
#  'そ-so',
#  'む-mu',
#  'ゆ-yu',
#  'い-i',
#  'お-o',
#  'か-ka',
#  'く-ku',
#  'と-to',
#  'ね-ne',
#  'の-no',
#  'ま-ma',
#  'く-ku',
#  'ら-ra',
#  'わ-wa',
#  'お-o',
#  'き-ki',
#  'こ-ko',
#  'せ-se',
#  'そ-so',
#  'た-ta',
#  'ち-chi',
#  'さ-sa',
#  'て-te',
#  'に-ni',
#  'ぬ-nu',
#  'ね-ne',
#  'み-mi',
#  'り-ri',
#  'ろ-ro',
#  'ん-n',
#  'え-e',
#  'く-ku',
#  'そ-so',
#  'せ-se',
#  'と-to',
#  'ぬ-nu',
#  'の-no',
#  'ふ-fu',
#  'ま-ma',
#  'む-mu',
#  'も-mo',
#  'よ-yo',
#  'ろ-ro',
#  'わ-wa',
#  'え-e',
#  'お-o',
#  'く-ku',
#  'け-ke',
#  'た-ta',
#  'ち-chi',
#  'て-te',
#  'な-na',
#  'ふ-fu',
#  'め-me',
#  'る-ru',
#  'ろ-ro',
#  'あ-a',
#  'う-u',
#  'か-ka',
#  'く-ku',
#  'こ-ko',
#  'す-su',
#  'た-ta',
#  'つ-tsu',
#  'ふ-fu',
#  'ほ-ho',
#  'は-ha',
#  'な-na',
#  'み-mi',
#  'や-ya',
#  'ゆ-yu',
#  'れ-re',
#  'わ-wa',
#  'か-ka',
#  'く-ku',
#  'し-shi',
#  'た-ta',
#  'ほ-ho',
#  'よ-yo',
#  'り-ri',
#  'れ-re',
#  'を-o',
#  'う-u',
#  'く-ku',
#  'こ-ko',
#  'め-me',
#  'て-te',
#  'ぬ-nu',
#  'へ-he',
#  'ま-ma',
#  'み-mi',
#  'む-mu',
#  'め-me',
#  'り-ri',
#  'れ-re',
#  'ろ-ro',
#  'を-o',
#  'ん-n',
#  'あ-a',
#  'う-u',
#  'か-ka',
#  'け-ke',
#  'さ-sa',
#  'す-su',
#  'せ-se',
#  'つ-tsu',
#  'な-na',
#  'ね-ne',
#  'へ-he',
#  'ま-ma',
#  'む-mu',
#  'る-ru',
#  'ろ-ro',
#  'わ-wa',
#  'あ-a',
#  'い-i',
#  'た-ta',
#  'て-te',
#  'と-to',
#  'な-na',
#  'ぬ-nu',
#  'の-no',
#  'わ-wa',
#  'め-me',
#  'を-o',
#  'よ-yo',
#  'ら-ra',
#  'る-ru',
#  'き-ki',
#  'と-to',
#  'な-na',
#  'ね-ne',
#  'は-ha',
#  'う-u',
#  'み-mi',
#  'む-mu',
#  'ゆ-yu',
#  'お-o',
#  'せ-se',
#  'た-ta',
#  'つ-tsu',
#  'て-te',
#  'き-ki',
#  'く-ku',
#  'り-ri',
#  'る-ru',
#  'け-ke',
#  'え-e',
#  'お-o',
#  'く-ku',
#  'こ-ko',
#  'す-su',
#  'せ-se',
#  'て-te',
#  'な-na',
#  'ひ-hi',
#  'ほ-ho',
#  'ま-ma',
#  'み-mi',
#  'め-me',
#  'も-mo',
#  'よ-yo',
#  'ん-n',
#  'あ-a',
#  'い-i',
#  'う-u',
#  'く-ku',
#  'こ-ko',
#  'し-shi',
#  'そ-so',
#  'た-ta',
#  'つ-tsu',
#  'て-te',
#  'と-to',
#  'ぬ-nu',
#  'へ-he',
#  'ほ-ho',
#  'よ-yo',
#  'ろ-ro',
#  'を-o',
#  'い-i',
#  'う-u',
#  'た-ta',
#  'つ-tsu',
#  'ひ-hi',
#  'へ-he',
#  'ほ-ho',
#  'よ-yo',
#  'り-ri',
#  'あ-a',
#  'な-na',
#  'に-ni',
#  'ね-ne',
#  'ひ-hi',
#  'は-ha',
#  'や-ya',
#  'ゆ-yu',
#  'よ-yo',
#  'り-ri',
#  'れ-re',
#  'わ-wa',
#  'を-o',
#  'ふ-fu',
#  'お-o',
#  'く-ku',
#  'こ-ko',
#  'す-su',
#  'ち-chi',
#  'つ-tsu',
#  'は-ha',
#  'む-mu',
#  'や-ya',
#  'り-ri',
#  'え-e',
#  'お-o',
#  'く-ku',
#  'け-ke',
#  'せ-se',
#  'て-te',
#  'は-ha',
#  'ふ-fu',
#  'も-mo',
#  'ら-ra',
#  'る-ru',
#  'ん-n',
#  'あ-a',
#  'い-i',
#  'ゆ-yu',
#  'す-su',
#  'そ-so',
#  'た-ta',
#  'つ-tsu',
#  'と-to',
#  'ら-ra',
#  'は-ha',
#  'ふ-fu',
#  'へ-he',
#  'や-ya',
#  'り-ri',
#  'れ-re',
#  'わ-wa',
#  'え-e',
#  'れ-re',
#  'す-su',
#  'せ-se',
#  'ろ-ro',
#  'て-te',
#  'に-ni',
#  'ひ-hi',
#  'ほ-ho',
#  'め-me',
#  'や-ya',
#  'ゆ-yu',
#  'ん-n',
#  'え-e',
#  'く-ku',
#  'こ-ko',
#  'あ-a',
#  'さ-sa',
#  'せ-se',
#  'そ-so',
#  'と-to',
#  'な-na',
#  'ね-ne',
#  'う-u',
#  'み-mi',
#  'ゆ-yu',
#  'よ-yo',
#  'ふ-fu',
#  'ろ-ro',
#  'あ-a',
#  'い-i',
#  'え-e',
#  'か-ka',
#  'に-ni',
#  'き-ki',
#  'ほ-ho',
#  'よ-yo',
#  'け-ke',
#  'え-e',
#  'お-o',
#  'す-su',
#  'そ-so',
#  'た-ta',
#  'さ-sa',
#  'と-to',
#  'ぬ-nu',
#  'は-ha',
#  'ふ-fu',
#  'ほ-ho',
#  'み-mi',
#  'を-o',
#  'ん-n',
#  'あ-a',
#  'い-i',
#  'お-o',
#  'き-ki',
#  'そ-so',
#  'て-te',
#  'た-ta',
#  'は-ha',
#  'へ-he',
#  'み-mi',
#  'ち-chi',
#  'や-ya',
#  'よ-yo',
#  'ら-ra',
#  'り-ri',
#  'く-ku',
#  'そ-so',
#  'ぬ-nu',
#  'ね-ne',
#  'な-na',
#  'ひ-hi',
#  'み-mi',
#  'め-me',
#  'に-ni',
#  'り-ri',
#  'を-o',
#  'ぬ-nu',
#  'あ-a',
#  'の-no',
#  'ね-ne',
#  'は-ha',
#  'ふ-fu',
#  'ほ-ho',
#  'は-ha',
#  'ま-ma',
#  'ゆ-yu',
#  'り-ri',
#  'ひ-hi',
#  'ん-n',
#  'か-ka',
#  'こ-ko',
#  'さ-sa',
#  'す-su',
#  'せ-se',
#  'へ-he',
#  'な-na',
#  'ぬ-nu',
#  'ほ-ho',
#  'ひ-hi',
#  'ま-ma',
#  'み-mi',
#  'む-mu',
#  'わ-wa',
#  'を-o',
#  'ん-n',
#  'い-i',
#  'く-ku',
#  'ぬ-nu',
#  'は-ha',
#  'へ-he',
#  'め-me',
#  'や-ya',
#  'あ-a',
#  'う-u',
#  'き-ki',
#  'よ-yo',
#  'て-te',
#  'と-to',
#  'ら-ra',
#  'ら-ra',
#  'れ-re',
#  'ん-n',
#  'あ-a',
#  'い-i',
#  'か-ka',
#  'き-ki',
#  'け-ke',
#  'す-su',
#  'な-na',
#  'に-ni',
#  'み-mi',
#  'ひ-hi',
#  'ほ-ho',
#  'ま-ma',
#  'や-ya',
#  'り-ri',
#  'わ-wa',
#  'あ-a',
#  'う-u',
#  'お-o',
#  'あ-a',
#  'さ-sa',
#  'た-ta',
#  'い-i',
#  'の-no',
#  'ひ-hi',
#  'へ-he',
#  'ほ-ho',
#  'う-u',
#  'む-mu',
#  'や-ya',
#  'ゆ-yu',
#  'り-ri',
#  'え-e',
#  'た-ta',
#  'つ-tsu',
#  'て-te',
#  'ま-ma',
#  'む-mu',
#  'や-ya',
#  'り-ri',
#  'る-ru',
#  'わ-wa',
#  'お-o',
#  'こ-ko',
#  'す-su',
#  'そ-so',
#  'た-ta',
#  'ち-chi',
#  'さ-sa',
#  'な-na',
#  'ほ-ho',
#  'み-mi',
#  'も-mo',
#  'よ-yo',
#  'す-su',
#  'ら-ra',
#  'え-e',
#  'け-ke',
#  'そ-so',
#  'す-su',
#  'せ-se',
#  'な-na',
#  'た-ta',
#  'ふ-fu',
#  'ほ-ho',
#  'ま-ma',
#  'め-me',
#  'も-mo',
#  'や-ya',
#  'よ-yo',
#  'つ-tsu',
#  'わ-wa',
#  'い-i',
#  'お-o',
#  'き-ki',
#  'け-ke',
#  'そ-so',
#  'た-ta',
#  'つ-tsu',
#  'や-ya',
#  'わ-wa',
#  'く-ku',
#  'て-te',
#  'と-to',
#  'の-no',
#  'な-na',
#  'ぬ-nu',
#  'の-no',
#  'ひ-hi',
#  'ほ-ho',
#  'む-mu',
#  'も-mo',
#  'よ-yo',
#  'ら-ra',
#  'れ-re',
#  'も-mo',
#  'き-ki',
#  'く-ku',
#  'し-shi',
#  'は-ha',
#  'ひ-hi',
#  'ふ-fu',
#  'ま-ma',
#  'よ-yo',
#  'あ-a',
#  'え-e',
#  'か-ka',
#  'き-ki',
#  'こ-ko',
#  'し-shi',
#  'せ-se',
#  'な-na',
#  'ね-ne',
#  'は-ha',
#  'も-mo',
#  'へ-he',
#  'ま-ma',
#  'を-o',
#  'え-e',
#  'き-ki',
#  'く-ku',
#  'し-shi',
#  'や-ya',
#  'す-su',
#  'せ-se',
#  'そ-so',
#  'つ-tsu',
#  'て-te',
#  'ら-ra',
#  'む-mu',
#  'も-mo',
#  'ら-ra',
#  'ん-n',
#  'う-u',
#  'お-o',
#  'か-ka',
#  'き-ki',
#  'し-shi',
#  'た-ta',
#  'て-te',
#  'な-na',
#  'ひ-hi',
#  'へ-he',
#  'ほ-ho',
#  'め-me',
#  'を-o',
#  'ゆ-yu',
#  'よ-yo',
#  'わ-wa',
#  'を-o',
#  'う-u',
#  'く-ku',
#  'す-su',
#  'そ-so',
#  'た-ta',
#  'ぬ-nu',
#  'は-ha',
#  'ゆ-yu',
#  'よ-yo',
#  'を-o',
#  'お-o',
#  'き-ki',
#  'こ-ko',
#  'し-shi',
#  'ち-chi',
#  'つ-tsu',
#  'と-to',
#  'ぬ-nu',
#  'ひ-hi',
#  'へ-he',
#  'も-mo',
#  'や-ya',
#  'ゆ-yu',
#  'わ-wa',
#  'を-o',
#  'い-i',
#  'か-ka',
#  'き-ki',
#  'こ-ko',
#  'こ-ko',
#  'ち-chi',
#  'つ-tsu',
#  'さ-sa',
#  'て-te',
#  'な-na',
#  'に-ni',
#  'の-no',
#  'は-ha',
#  'ほ-ho',
#  'や-ya',
#  'す-su',
#  'り-ri',
#  'る-ru',
#  'れ-re',
#  'を-o',
#  'す-su',
#  'せ-se',
#  'ぬ-nu',
#  'は-ha',
#  'ひ-hi',
#  'ふ-fu',
#  'ち-chi',
#  'よ-yo',
#  'る-ru',
#  'を-o',
#  'い-i',
#  'う-u',
#  'お-o',
#  'き-ki',
#  'け-ke',
#  'す-su',
#  'そ-so',
#  'つ-tsu',
#  'ね-ne',
#  'ひ-hi',
#  'へ-he',
#  'ま-ma',
#  'み-mi',
#  'に-ni',
#  'ら-ra',
#  'ゆ-yu',
#  'る-ru',
#  'ろ-ro',
#  'わ-wa',
#  'う-u',
#  'く-ku',
#  'ね-ne',
#  'し-shi',
#  'す-su',
#  'た-ta',
#  'ち-chi',
#  'に-ni',
#  'ね-ne',
#  'ふ-fu',
#  'へ-he',
#  'む-mu',
#  'め-me',
#  'も-mo',
#  'よ-yo',
#  'り-ri',
#  'る-ru',
#  'ん-n',
#  'い-i',
#  'う-u',
#  'ふ-fu',
#  'か-ka',
#  'き-ki',
#  'け-ke',
#  'ぬ-nu',
#  'は-ha',
#  'ふ-fu',
#  'ま-ma',
#  'も-mo',
#  'ろ-ro',
#  'わ-wa',
#  'え-e',
#  'あ-a',
#  'え-e',
#  'か-ka',
#  'む-mu',
#  'さ-sa',
#  'し-shi',
#  'せ-se',
#  'た-ta',
#  'と-to',
#  'の-no',
#  'ほ-ho',
#  'ゆ-yu',
#  'よ-yo',
#  'や-ya',
#  'り-ri',
#  'い-i',
#  'う-u',
#  'え-e',
#  'け-ke',
#  'さ-sa',
#  'よ-yo',
#  'す-su',
#  'つ-tsu',
#  'と-to',
#  'は-ha',
#  'み-mi',
#  'や-ya',
#  'い-i',
#  'う-u',
#  'き-ki',
#  'け-ke',
#  'ち-chi',
#  'に-ni',
#  'ひ-hi',
#  'へ-he',
#  'み-mi',
#  'も-mo',
#  'よ-yo',
#  'ら-ra',
#  'あ-a',
#  'う-u',
#  'お-o',
#  'こ-ko',
#  'そ-so',
#  'て-te',
#  'の-no',
#  'ほ-ho',
#  'う-u',
#  'む-mu',
#  'よ-yo',
#  'れ-re',
#  'わ-wa',
#  'を-o',
#  'ん-n',
#  'こ-ko',
#  'し-shi',
#  'か-ka',
#  'れ-re',
#  'そ-so',
#  'た-ta',
#  'て-te',
#  'な-na',
#  'は-ha',
#  'へ-he',
#  'め-me',
#  'も-mo',
#  'よ-yo',
#  'ら-ra',
#  'い-i',
#  'え-e',
#  'こ-ko',
#  'さ-sa',
#  'ぬ-nu',
#  'ひ-hi',
#  'ふ-fu',
#  'よ-yo',
#  'を-o',
#  'あ-a',
#  'う-u',
#  'ち-chi',
#  'つ-tsu',
#  'て-te',
#  'た-ta',
#  'ひ-hi',
#  'へ-he',
#  'め-me',
#  'や-ya',
#  'よ-yo',
#  'る-ru',
#  'を-o',
#  'え-e',
#  'き-ki',
#  'け-ke',
#  'さ-sa',
#  'し-shi',
#  'た-ta',
#  'と-to',
#  'ひ-hi',
#  'へ-he',
#  'ほ-ho',
#  'む-mu',
#  'も-mo',
#  'ら-ra',
#  'る-ru',
#  'れ-re',
#  'あ-a',
#  'う-u',
#  'お-o',
#  'か-ka',
#  'く-ku',
#  'こ-ko',
#  'し-shi',
#  'す-su',
#  'そ-so',
#  'つ-tsu',
#  'な-na',
#  'ぬ-nu',
#  'ね-ne',
#  'の-no',
#  'む-mu',
#  'り-ri',
#  'ろ-ro',
#  'わ-wa',
#  'を-o',
#  'あ-a',
#  'ふ-fu',
#  'か-ka',
#  'け-ke',
#  'さ-sa',
#  'す-su',
#  'せ-se',
#  'の-no',
#  'へ-he',
#  'め-me',
#  'り-ri',
#  'る-ru',
#  'れ-re',
#  'を-o',
#  'い-i',
#  'き-ki',
#  'む-mu',
#  'こ-ko',
#  'せ-se',
#  'ち-chi',
#  'に-ni',
#  'は-ha',
#  'ふ-fu',
#  'も-mo',
#  'ま-ma',
#  'む-mu',
#  'め-me',
#  ...]

# %% [markdown]
# <h1> Data Augmentation </h1>

# %%
# Load image of the train first

x_train = []
y_train = []
for idx, path in enumerate(x_train_path):
    # Check do the classes is katakana
    type_chara = x_train_path[idx].split("//")[2].split("_")[2].split(".")[0]
    if type_chara == "kana":
        continue

    label = x_train_path[idx].split("//")[2].split("\\")[1].split("_")[1]
    y_train.append(label)
    
    img_temp = cv2.imread(path)
    img_temp = cv2.cvtColor(img_temp, cv2.COLOR_BGR2RGB)
    x_train.append(img_temp)

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder().fit(y_train)
y_train = le.transform(y_train)
y_test = le.transform(y_test)

# %%
len(x_train)

plt.imshow(x_train[100])
print(japanese_character[y_train[100]])
print(x_train_path[100])
# Out:
# さ-sa
# dataset//ETL1C//IMG\10126_タ-ta_kana.png

# %%
from collections import Counter

counter = Counter(np.sort(y_train))
for k, v in counter.items():
    per= v / len(y_train) * 100
    print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
# Out:
# Class=0, n=271 (2.170%)
# Class=1, n=271 (2.170%)
# Class=2, n=272 (2.178%)
# Class=3, n=271 (2.170%)
# Class=4, n=272 (2.178%)
# Class=5, n=271 (2.170%)
# Class=6, n=272 (2.178%)
# Class=7, n=271 (2.170%)
# Class=8, n=272 (2.178%)
# Class=9, n=272 (2.178%)
# Class=10, n=271 (2.170%)
# Class=11, n=272 (2.178%)
# Class=12, n=271 (2.170%)
# Class=13, n=272 (2.178%)
# Class=14, n=271 (2.170%)
# Class=15, n=272 (2.178%)
# Class=16, n=271 (2.170%)
# Class=17, n=272 (2.178%)
# Class=18, n=271 (2.170%)
# Class=19, n=272 (2.178%)
# Class=20, n=271 (2.170%)
# Class=21, n=272 (2.178%)
# Class=22, n=271 (2.170%)
# Class=23, n=272 (2.178%)
# Class=24, n=271 (2.170%)
# Class=25, n=272 (2.178%)
# Class=26, n=271 (2.170%)
# Class=27, n=272 (2.178%)
# Class=28, n=271 (2.170%)
# Class=29, n=272 (2.178%)
# Class=30, n=271 (2.170%)
# Class=31, n=272 (2.178%)
# Class=32, n=271 (2.170%)
# Class=33, n=272 (2.178%)
# Class=34, n=272 (2.178%)
# Class=35, n=271 (2.170%)
# Class=36, n=272 (2.178%)
# Class=37, n=271 (2.170%)
# Class=38, n=272 (2.178%)
# Class=39, n=271 (2.170%)
# Class=40, n=272 (2.178%)
# Class=41, n=271 (2.170%)
# Class=42, n=272 (2.178%)
# Class=43, n=271 (2.170%)
# Class=44, n=271 (2.170%)
# Class=45, n=272 (2.178%)

# %% [markdown]
# <h4> List Augmented Method </h4>
# 1. Resize 48 px </br>
# 2. Resize 36 px </br>
# 3. Erotion </br>
# 4. Dilation </br>
# 5. Brightness

# %%
def brightness_settings(img, brightness=255):    
    if brightness != 0:
        if brightness > 0:
            shadow = brightness
            highlight = 255
        else:
            shadow = 0
            highlight = 255 + brightness
        alpha_b = (highlight - shadow)/255
        gamma_b = shadow
        buf = cv2.addWeighted(img, alpha_b, img, 0, gamma_b)
    else:
        buf = img.copy()
        
    return buf

def morphological_action(img, action):
    kernel = np.ones((1, 1), np.uint8)
    if action == 'dilation':
        return cv2.erode(img, kernel, iterations=1)
    if action == 'erosion':
        return cv2.dilate(img, kernel, iterations=1)
    
def rotation(img, direction='left', degree=45):
    rows, cols = img.shape[0], img.shape[1]
    img_center = (cols / 2, rows / 2)
    
    if direction == 'left':
        rotate_mat = cv2.getRotationMatrix2D(img_center, degree, 1)
    else:
        rotate_mat = cv2.getRotationMatrix2D(img_center, 360-degree, 1)
    
    return cv2.warpAffine(img, rotate_mat, (cols, rows), 
                          borderMode=cv2.BORDER_CONSTANT,
                          borderValue=(255, 255, 255))

# %%
# First Augment
# 0. No Augment
# 1. Erosion
# 2. Dilation
# 3. brightness

# Rotation
# 0. No rotation
# 1. Resize 48
# 2. Resize 36

import random

def generate_random_combination(n_combination=2):
    combination = []
    
    itr = 0
    # Looping to generate n combination
    # Only possible for 11 combination, if 11 combination has been fulfilled loop may go infinity
    while itr < n_combination:
        # Generate with range 0f 0-3 and 0-2
        temp = [random.randrange(0, 4), random.randrange(0, 3)]
        
        # Avoid combination [0, 0]
        if temp == [0, 0]:
            continue
        
        # Assign for first iteration
        if itr == 0:
            combination.append(temp)
            itr += 1
        
        # Assign for second and later iteration
        if itr != 0:      
            # Gather Information upwards/backward of array
            isTheSame = False
            for data in combination:
                if data == temp:
                    isTheSame = True
                    break
                    
            # if no similiarity to backward array temp succesfully added
            if isTheSame == False:
                combination.append(temp)
                itr += 1
            else:
                continue

    return np.asarray(combination)

# %%
 # Lets Augment
n_augmentation_combination = 8

augmented_x = []
augmented_y = []
for idx, character in enumerate(japanese_character):
    # Generate Random Combination for augmentation Each Classes
    combination = generate_random_combination(n_augmentation_combination)

    # Eliminate empty combination(Eg. Class which dont need any augmentation)
    if len(combination) == 0:
        continue
    
    # loop the Combination array
    current_class = idx
    for idx_comb, combinated in enumerate(combination):
        # Loop Through the image
        for idx_img, img in enumerate(x_train):
            if y_train[idx_img] == current_class:
                temp = img
                # Check for the first Augmentation
                
                if combinated[0] == 1:
                    temp = morphological_action(temp, action='erosion')
                if combinated[0] == 2:
                    temp = morphological_action(temp, action='dilation')
                if combinated[0] == 3:
                    temp = brightness_settings(temp, brightness=50)
                    
                if combinated[1] == 1:
                    #temp = rotation(temp, direction='left', degree=45)
                    temp = cv2.resize(temp, (48, 48))
                if combinated[1] == 2:
                    temp = cv2.resize(temp, (36, 36))
                        
                augmented_x.append(temp)
                augmented_y.append(current_class)

# %%
len(augmented_y)
# Out:
# 99912

# %% [markdown]
# <h2> Validating </h2>

# %%
test = augmented_x[1200]
print(augmented_y[1200], japanese_character[augmented_y[1200]])
plt.imshow(test)
# Out:
# 0 あ-a

# %%
test = augmented_x[20006]
print(augmented_y[20006], japanese_character[augmented_y[20006]])
plt.imshow(test)
# Out:
# 9 こ-ko

# %% [markdown]
# <h2> Saving </h2>

# %%
y_train = y_train.tolist()

x_train.extend(augmented_x)
y_train.extend(augmented_y)

# %%
print(len(x_train), len(y_train))
# Out:
# 112401 112401

# %%
counter = Counter(np.sort(y_train))
for k, v in counter.items():
    per= v / len(y_train) * 100
    print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
# Out:
# Class=0, n=2439 (2.170%)
# Class=1, n=2439 (2.170%)
# Class=2, n=2448 (2.178%)
# Class=3, n=2439 (2.170%)
# Class=4, n=2448 (2.178%)
# Class=5, n=2439 (2.170%)
# Class=6, n=2448 (2.178%)
# Class=7, n=2439 (2.170%)
# Class=8, n=2448 (2.178%)
# Class=9, n=2448 (2.178%)
# Class=10, n=2439 (2.170%)
# Class=11, n=2448 (2.178%)
# Class=12, n=2439 (2.170%)
# Class=13, n=2448 (2.178%)
# Class=14, n=2439 (2.170%)
# Class=15, n=2448 (2.178%)
# Class=16, n=2439 (2.170%)
# Class=17, n=2448 (2.178%)
# Class=18, n=2439 (2.170%)
# Class=19, n=2448 (2.178%)
# Class=20, n=2439 (2.170%)
# Class=21, n=2448 (2.178%)
# Class=22, n=2439 (2.170%)
# Class=23, n=2448 (2.178%)
# Class=24, n=2439 (2.170%)
# Class=25, n=2448 (2.178%)
# Class=26, n=2439 (2.170%)
# Class=27, n=2448 (2.178%)
# Class=28, n=2439 (2.170%)
# Class=29, n=2448 (2.178%)
# Class=30, n=2439 (2.170%)
# Class=31, n=2448 (2.178%)
# Class=32, n=2439 (2.170%)
# Class=33, n=2448 (2.178%)
# Class=34, n=2448 (2.178%)
# Class=35, n=2439 (2.170%)
# Class=36, n=2448 (2.178%)
# Class=37, n=2439 (2.170%)
# Class=38, n=2448 (2.178%)
# Class=39, n=2439 (2.170%)
# Class=40, n=2448 (2.178%)
# Class=41, n=2439 (2.170%)
# Class=42, n=2448 (2.178%)
# Class=43, n=2439 (2.170%)
# Class=44, n=2439 (2.170%)
# Class=45, n=2448 (2.178%)

# %%
import os

# Saving for Train
for idx, img in enumerate(x_train):
    img_format_string = str(idx) + "_" + japanese_character[y_train[idx]] +  "_" + str(y_train[idx]) + "_train_" + ".png"
    #saving_string = os.path.join("Dataset", "Train_", img_format_string)
    save2 = os.path.join("full_dataset", "train", img_format_string)

    cv2.imwrite(save2, img)
    #cv2.imwrite(save2, cv2.resize(img, (64, 64)))

# %%
# Saving for test
for idx, img in enumerate(x_test):
    img_format_string = str(idx) + "_" + japanese_character[y_test[idx]] +  "_" + str(y_test[idx]) + "_test_" + ".png"
    saving_string = os.path.join("Dataset", "Test_", img_format_string)
    save2 = os.path.join("full_dataset", "test", img_format_string)
    
    cv2.imwrite(save2, img)
    #cv2.imwrite(saving_string, img)

# %% [markdown]
# <h2> Testing </h2>

# %%
test_img = morphological_action(x_train[1000], action='erosion')
plt.imshow(test_img)
